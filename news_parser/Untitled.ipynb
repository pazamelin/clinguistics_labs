# %%
import sys
import subprocess
import pkg_resources

required = {'numpy', 'pandas'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)

# %%
import numpy as np
import pandas as pd
import json

# %%
DATASET_PATH = './artifacts/merged.json'

# %%
dataset = None
with open(DATASET_PATH) as json_file:
    dataset_raw = json.load(json_file)
    columns = dataset_raw['catalog'][0].keys()
    dataset = pd.DataFrame(columns=columns, data=dataset_raw['catalog'])
    
# transormations
for index, row in dataset.iterrows():
    if row['category'] == '#comp-comments':
        row['article_id'] = row['article_id'][:-len('/#comp-comments-button')]
        url = row['article_id']
        row['category'] = url[url.rfind('/')+1:url.rfind('-')]
        
dataset
# Out:
#                                               article_id  \
# 0        http://www.bbc.co.uk/news/world-europe-55497084
# 1      http://www.bbc.co.uk/news/uk-northern-ireland-...
# 2            http://www.bbc.co.uk/news/business-55494101
# 3      http://www.bbc.co.uk/news/uk-england-merseysid...
# 4                  http://www.bbc.co.uk/news/uk-55502595
# ...                                                  ...
# 23602  http://www.bbc.co.uk/news/world-australia-5947...
# 23603      http://www.bbc.co.uk/news/explainers-52544307
# 23604  http://www.bbc.co.uk/news/world-middle-east-59...
# 23605        http://www.bbc.co.uk/news/business-59466803
# 23606      http://www.bbc.co.uk/news/world-asia-59457607
#
#                     category  \
# 0               world-europe
# 1        uk-northern-ireland
# 2                   business
# 3      uk-england-merseyside
# 4                         uk
# ...                      ...
# 23602        world-australia
# 23603             explainers
# 23604      world-middle-east
# 23605               business
# 23606             world-asia
#
#                                                    title  \
# 0      Brexit: Gibraltar gets UK-Spain deal to keep o...
# 1      Covid-19: Homeschooling returns for first week...
# 2           Adieu to the single market created by the UK
# 3      Joe Anderson: Liverpool mayor in police probe ...
# 4       Covid-19: UK reports a record 55,892 daily cases
# ...                                                  ...
# 23602  Australian parliament: One in three workers se...
# 23603  What Covid tests do I still need to travel abr...
# 23604     Yemen: The children haunted by 'ghosts' of war
# 23605  Facial recognition firm faces possible £17m pr...
# 23606  China: Moment North Korean inmate breaks out o...
#
#                                                     tags  \
# 0      Gibraltar,Spain,Effects of Brexit on Gibraltar...
# 1      NI education,Coronavirus lockdown measures,Cor...
# 2      Companies,EU-UK post-Brexit trade talks,Boris ...
# 3                       Liverpool City Council,Liverpool
# 4                        Healthcare,Coronavirus pandemic
# ...                                                  ...
# 23602                        Sexual harassment,Australia
# 23603  Tourism,Spain,France,Coronavirus lockdown meas...
# 23604                                                NaN
# 23605  Facial recognition,Information Commissioner's ...
# 23606                                                NaN
#
#                                                     text
# 0      Spain has reached a deal with the UK to mainta...
# 1      Most pupils in Northern Ireland will not be re...
# 2      Nearly half a century of the UK's membership o...
# 3      Liverpool Mayor Joe Anderson says he will not ...
# 4      The UK has reported another 55,892 daily cases...
# ...                                                  ...
# 23602  A third of employees in Australia's federal pa...
# 23603  From next month, fully vaccinated people trave...
# 23604
# 23605  An Australian firm which claims to have a data...
# 23606
#
# [23607 rows x 5 columns]

# %%
dataset['category'].value_counts()[:20]
# Out:
# uk                               3507
# business                         2323
# uk-wales                         1936
# health                           1457
# world-us-canada                  1414
# uk-politics                      1389
# uk-northern-ireland              1231
# world-europe                     1015
# uk-scotland                       863
# entertainment-arts                833
# world-asia                        672
# science-environment               565
# uk-england-london                 559
# explainers                        435
# technology                        409
# education                         337
# uk-wales-politics                 331
# world-middle-east                 315
# uk-scotland-scotland-politics     266
# world                             247
# Name: category, dtype: int64
